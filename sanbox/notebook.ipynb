# %%
import requests

# %%
BASE_URL = 'http://localhost:8000/'

# %%
res = requests.post(
    f'{BASE_URL}/v1/single-chat',
    json={'message': 'こんにちは'}
)

# %%
res.text
# Out:
# '{"message":"こんにちは！今日はどんな楽しいことを話しましょうか？😊"}'
